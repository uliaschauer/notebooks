# %%
from pylab import *
from ipywidgets import *
import matplotlib.patches as patches
# %matplotlib notebook

#initial values
n0=1

#create data
x = arange(0, 1, 0.001)
def psi(x, n):
    return sqrt(2)*sin(n * pi * x)
y = psi(x, n0)

#create plot
fig1 = figure()
ax1 = fig1.add_subplot(111)
curve1, = plot(x, y, lw=2, color='red')
axis([-0.5, 1.5, -1.5, 1.5])
xlabel('x')
ylabel('Wellenfunktion')
p = ax1.add_patch(patches.Rectangle((-1.0, -1.5), 1.0, 4.0, alpha=0.2))
p = ax1.add_patch(patches.Rectangle((1.0, -1.5), 1.0, 4.0, alpha=0.2))

@interact(n=(1,100), probability=False)
def update(n=n0, probability=False):
    if not probability:
        curve1.set_ydata(psi(x, n))
        ylabel('Wellenfunktion')
        axis([-0.5, 1.5, -1.5, 1.5])
    else:
        curve1.set_ydata(psi(x, n)**2)
        ylabel('Wahrscheinlichkeitsdichte')
        axis([-0.5, 1.5, 0, 2.5])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
