# %%
from pylab import *
from ipywidgets import *
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook

#initial values
n10=2
n20=1

#create data
x = arange(0, 1, 0.04)
y = arange(0, 1, 0.04)
x, y = np.meshgrid(x, y)
def psi(x, y, n1, n2):
    return 2*sin(n1*pi*x)*sin(n2*pi*y)
z = psi(x, y, n10, n20)

#create plot
fig1 = figure()
ax1 = fig1.gca(projection='3d')
surf = ax1.plot_surface(x, y, z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0.2)
xlabel('x')
ylabel('y')

@interact(n1=(1,5), n2=(1,5))
def update(n1=n10, n2=n20):
    z = psi(x, y, n1, n2)
    global surf
    surf.remove()
    surf = ax1.plot_surface(x, y, z, rstride=1, cstride=1, cmap=cm.coolwarm, linewidth=0.2)
    draw()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
